# %%
# import libraries we will use
import warnings
warnings.filterwarnings('ignore')

# matplotlib for plotting
from matplotlib import pyplot as plt
import matplotlib
# matplotlib.style.use('ggplot')
# %matplotlib inline

# seaborn for plotting
# import seaborn as sns

# pandas for dataframes
import pandas as pd
pd.options.display.max_columns = 100
pd.options.display.max_rows = 100

# numpy for linear algebra
import numpy as np

# sklearn for machine learning libraries
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.cross_validation import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

# %%
# load training set into a pandas dataframe
train_data = pd.read_csv('./train.csv')

# %%
# load test set into a pandas dataframe
test_data = pd.read_csv('./test.csv')

# %%
# train_data['BldgTypeCategory'] = -1

# %%
# train_data['BldgTypeCategory'][train_data['BldgType'] == '1Fam'] = 1
# train_data['BldgTypeCategory'][train_data['BldgType'] == '2fmCon'] = 2
# train_data['BldgTypeCategory'][train_data['BldgType'] == 'Duplex'] = 3
# train_data['BldgTypeCategory'][train_data['BldgType'] == 'TwnhsE'] = 4 
# train_data['BldgTypeCategory'][train_data['BldgType'] == 'Twnhs'] = 5

# %%
# train_data[['BldgTypeCategory', 'BldgType']]

# %%
train_data.head(5)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
train_data.info
# Out:
# <bound method DataFrame.info of         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# 5        6          50       RL         85.0    14115   Pave   NaN      IR1
# 6        7          20       RL         75.0    10084   Pave   NaN      Reg
# 7        8          60       RL          NaN    10382   Pave   NaN      IR1
# 8        9          50       RM         51.0     6120   Pave   NaN      Reg
# 9       10         190       RL         50.0     7420   Pave   NaN      Reg
# 10      11          20       RL         70.0    11200   Pave   NaN      Reg
# ...

# %%
test_data.head(5)
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 2         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 3         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 4         HLS    AllPub    Inside       Gtl      StoneBr       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
train_data.shape
# Out:
# (1460, 81)

# %%
test_data.shape
# Out:
# (1459, 80)

# %%
train_data.count()
# Out:
# Id               1460
# MSSubClass       1460
# MSZoning         1460
# LotFrontage      1201
# LotArea          1460
# Street           1460
# Alley              91
# LotShape         1460
# LandContour      1460
# Utilities        1460
# LotConfig        1460
# LandSlope        1460
# Neighborhood     1460
# Condition1       1460
# Condition2       1460
# BldgType         1460
# HouseStyle       1460
# OverallQual      1460
# OverallCond      1460
# YearBuilt        1460
# YearRemodAdd     1460
# RoofStyle        1460
# RoofMatl         1460
# Exterior1st      1460
# Exterior2nd      1460
# MasVnrType       1452
# MasVnrArea       1452
# ExterQual        1460
# ExterCond        1460
# Foundation       1460
# BsmtQual         1423
# BsmtCond         1423
# BsmtExposure     1422
# BsmtFinType1     1423
# BsmtFinSF1       1460
# BsmtFinType2     1422
# BsmtFinSF2       1460
# BsmtUnfSF        1460
# TotalBsmtSF      1460
# Heating          1460
# HeatingQC        1460
# ...

# %%
test_data.count()
# Out:
# Id               1459
# MSSubClass       1459
# MSZoning         1455
# LotFrontage      1232
# LotArea          1459
# Street           1459
# Alley             107
# LotShape         1459
# LandContour      1459
# Utilities        1457
# LotConfig        1459
# LandSlope        1459
# Neighborhood     1459
# Condition1       1459
# Condition2       1459
# BldgType         1459
# HouseStyle       1459
# OverallQual      1459
# OverallCond      1459
# YearBuilt        1459
# YearRemodAdd     1459
# RoofStyle        1459
# RoofMatl         1459
# Exterior1st      1458
# Exterior2nd      1458
# MasVnrType       1443
# MasVnrArea       1444
# ExterQual        1459
# ExterCond        1459
# Foundation       1459
# BsmtQual         1415
# BsmtCond         1414
# BsmtExposure     1415
# BsmtFinType1     1417
# BsmtFinSF1       1458
# BsmtFinType2     1417
# BsmtFinSF2       1458
# BsmtUnfSF        1458
# TotalBsmtSF      1458
# Heating          1459
# HeatingQC        1459
# ...

# %%
print(train_data.groupby('GarageType').count())
# Out:
#              Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# GarageType
# 2Types        6           6         6            5        6       6      1
# Attchd      870         870       870          694      870     870     15
# Basment      19          19        19           15       19      19      0
# BuiltIn      88          88        88           65       88      88      0
# CarPort       9           9         9            8        9       9      0
# Detchd      387         387       387          340      387     387     66
#
#             LotShape  LandContour  Utilities  LotConfig  LandSlope  \
# GarageType
# 2Types             6            6          6          6          6
# Attchd           870          870        870        870        870
# Basment           19           19         19         19         19
# BuiltIn           88           88         88         88         88
# CarPort            9            9          9          9          9
# ...

# %%
def get_combined_data():
    # reading train data
    train = pd.read_csv('./train.csv')
    
    # reading test data
    test = pd.read_csv('./test.csv')

    # extracting and then removing the targets from the training data 
    targets_value = train.SalePrice
    train.drop('SalePrice',1,inplace=True)
    

    # merging train data and test data for future feature engineering
    combined = train.append(test)
    combined.reset_index(inplace=True)
    combined.drop('index',inplace=True,axis=1)
    
    return combined

# %%
combined = get_combined_data()

# %%
combined.shape
# Out:
# (2919, 80)

# %%
combined.GarageType.unique()
# Out:
# array(['Attchd', 'Detchd', 'BuiltIn', 'CarPort', nan, 'Basment', '2Types'], dtype=object)

# %%
combined.LotFrontage.unique()
# Out:
# array([  65.,   80.,   68.,   60.,   84.,   85.,   75.,   nan,   51.,
#          50.,   70.,   91.,   72.,   66.,  101.,   57.,   44.,  110.,
#          98.,   47.,  108.,  112.,   74.,  115.,   61.,   48.,   33.,
#          52.,  100.,   24.,   89.,   63.,   76.,   81.,   95.,   69.,
#          21.,   32.,   78.,  121.,  122.,   40.,  105.,   73.,   77.,
#          64.,   94.,   34.,   90.,   55.,   88.,   82.,   71.,  120.,
#         107.,   92.,  134.,   62.,   86.,  141.,   97.,   54.,   41.,
#          79.,  174.,   99.,   67.,   83.,   43.,  103.,   93.,   30.,
#         129.,  140.,   35.,   37.,  118.,   87.,  116.,  150.,  111.,
#          49.,   96.,   59.,   36.,   56.,  102.,   58.,   38.,  109.,
#         130.,   53.,  137.,   45.,  106.,  104.,   42.,   39.,  144.,
#         114.,  128.,  149.,  313.,  168.,  182.,  138.,  160.,  152.,
#         124.,  153.,   46.,   26.,   25.,  119.,   31.,   28.,  117.,
# ...

# %%
combined[combined.YrSold.isnull()]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition]
# Index: []

# %%
combined[combined.OpenPorchSF.isnull()]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition]
# Index: []

# %%
combined[combined.EnclosedPorch.isnull()]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition]
# Index: []

# %%
combined[combined.SaleCondition.isnull()]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition]
# Index: []

# %%
combined.SaleCondition.unique()
# Out:
# array(['Normal', 'Abnorml', 'Partial', 'AdjLand', 'Alloca', 'Family'], dtype=object)

# %%
combined[combined.SaleType.isnull()]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 2489  2490          20       RL         85.0    13770   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 2489         Lvl    AllPub    Corner       Gtl       Sawyer      Feedr
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 2489       Norm     1Fam     1Story            5            6       1958
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 2489          1998     Gable  CompShg     Plywood     Plywood    BrkFace
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 2489       340.0        TA        TA     CBlock       TA       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 2489           Mn          Rec       190.0          BLQ       873.0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# ...

# %%
combined.SaleType.unique()
# Out:
# array(['WD', 'New', 'COD', 'ConLD', 'ConLI', 'CWD', 'ConLw', 'Con', 'Oth',
#        nan], dtype=object)

# %%
combined.groupby('SaleType').count()
# Out:
#             Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# SaleType
# COD         87          87        87           71       87      87     12
# CWD         12          12        12           10       12      12      1
# Con          5           5         5            5        5       5      1
# ConLD       26          26        25           24       26      26      3
# ConLI        9           9         9            8        9       9      1
# ConLw        8           8         8            8        8       8      0
# New        239         239       239          235      239     239     14
# Oth          7           7         7            6        7       7      0
# WD        2525        2525      2522         2065     2525    2525    166
#
#           LotShape  LandContour  Utilities  LotConfig  LandSlope  \
# SaleType
# COD             87           87         87         87         87
# CWD             12           12         12         12         12
# ...

# %%
combined.SaleType=combined.SaleType.fillna('WD')

# %%
combined[combined.RoofStyle.isnull()]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition]
# Index: []

# %%
combined.SaleType.unique()
# Out:
# array(['WD', 'New', 'COD', 'ConLD', 'ConLI', 'CWD', 'ConLw', 'Con', 'Oth'], dtype=object)

# %%
combined.MSSubClass.unique()
# Out:
# array([ 60,  20,  70,  50, 190,  45,  90, 120,  30,  85,  80, 160,  75,
#        180,  40, 150])

# %%
combined.LotFrontage.unique()
# Out:
# array([  65.,   80.,   68.,   60.,   84.,   85.,   75.,   nan,   51.,
#          50.,   70.,   91.,   72.,   66.,  101.,   57.,   44.,  110.,
#          98.,   47.,  108.,  112.,   74.,  115.,   61.,   48.,   33.,
#          52.,  100.,   24.,   89.,   63.,   76.,   81.,   95.,   69.,
#          21.,   32.,   78.,  121.,  122.,   40.,  105.,   73.,   77.,
#          64.,   94.,   34.,   90.,   55.,   88.,   82.,   71.,  120.,
#         107.,   92.,  134.,   62.,   86.,  141.,   97.,   54.,   41.,
#          79.,  174.,   99.,   67.,   83.,   43.,  103.,   93.,   30.,
#         129.,  140.,   35.,   37.,  118.,   87.,  116.,  150.,  111.,
#          49.,   96.,   59.,   36.,   56.,  102.,   58.,   38.,  109.,
#         130.,   53.,  137.,   45.,  106.,  104.,   42.,   39.,  144.,
#         114.,  128.,  149.,  313.,  168.,  182.,  138.,  160.,  152.,
#         124.,  153.,   46.,   26.,   25.,  119.,   31.,   28.,  117.,
# ...

# %%
combined['LotFrontage']=combined.LotFrontage.fillna(combined.LotFrontage.median())

# %%
combined[combined.LotFrontage.isnull()]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition]
# Index: []

# %%
combined[combined.LotArea.isnull()]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition]
# Index: []

# %%
combined['BldgTypeCategory']=-1

# %%
combined['BldgTypeCategory'][combined['BldgType'] == '1Fam'] = 1
combined['BldgTypeCategory'][combined['BldgType'] == '2fmCon'] = 2
combined['BldgTypeCategory'][combined['BldgType'] == 'Duplex'] = 3
combined['BldgTypeCategory'][combined['BldgType'] == 'TwnhsE'] = 4 
combined['BldgTypeCategory'][combined['BldgType'] == 'Twnhs'] = 5

# %%
combined.drop('BldgType',1,inplace=True)

# %%
combined.head(5)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# ...

# %%
combined.Neighborhood.unique()
# Out:
# array(['CollgCr', 'Veenker', 'Crawfor', 'NoRidge', 'Mitchel', 'Somerst',
#        'NWAmes', 'OldTown', 'BrkSide', 'Sawyer', 'NridgHt', 'NAmes',
#        'SawyerW', 'IDOTRR', 'MeadowV', 'Edwards', 'Timber', 'Gilbert',
#        'StoneBr', 'ClearCr', 'NPkVill', 'Blmngtn', 'BrDale', 'SWISU',
#        'Blueste'], dtype=object)

# %%
combined['NeighbourCity']=-1

# %%
combined['NeighbourCity'][combined['Neighborhood'] == 'CollgCr'] = 1
combined['NeighbourCity'][combined['Neighborhood'] == 'Veenker'] = 2
combined['NeighbourCity'][combined['Neighborhood'] == 'Crawfor'] = 3
combined['NeighbourCity'][combined['Neighborhood'] == 'NoRidge'] = 4 
combined['NeighbourCity'][combined['Neighborhood'] == 'Mitchel'] = 5
combined['NeighbourCity'][combined['Neighborhood'] == 'Somerst'] = 6
combined['NeighbourCity'][combined['Neighborhood'] == 'NWAmes'] = 7
combined['NeighbourCity'][combined['Neighborhood'] == 'OldTown'] = 8
combined['NeighbourCity'][combined['Neighborhood'] == 'BrkSide'] = 9 
combined['NeighbourCity'][combined['Neighborhood'] == 'Sawyer'] = 10
combined['NeighbourCity'][combined['Neighborhood'] == 'NridgHt'] = 11
combined['NeighbourCity'][combined['Neighborhood'] == 'NAmes'] = 12
combined['NeighbourCity'][combined['Neighborhood'] == 'SawyerW'] = 13
combined['NeighbourCity'][combined['Neighborhood'] == 'IDOTRR'] = 14 
combined['NeighbourCity'][combined['Neighborhood'] == 'MeadowV'] = 15
combined['NeighbourCity'][combined['Neighborhood'] == 'Edwards'] = 16
combined['NeighbourCity'][combined['Neighborhood'] == 'Timber'] = 17
combined['NeighbourCity'][combined['Neighborhood'] == 'Gilbert'] = 18
combined['NeighbourCity'][combined['Neighborhood'] == 'StoneBr'] = 19 
combined['NeighbourCity'][combined['Neighborhood'] == 'ClearCr'] = 20
combined['NeighbourCity'][combined['Neighborhood'] == 'NPkVill'] = 21
combined['NeighbourCity'][combined['Neighborhood'] == 'Blmngtn'] = 22
combined['NeighbourCity'][combined['Neighborhood'] == 'BrDale'] = 23
combined['NeighbourCity'][combined['Neighborhood'] == 'SWISU'] = 24 
combined['NeighbourCity'][combined['Neighborhood'] == 'Blueste'] = 25

# %%
combined.drop('Neighborhood',1,inplace=True)

# %%
combined.head(5)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Condition1 Condition2 HouseStyle  \
# 0         Lvl    AllPub    Inside       Gtl       Norm       Norm     2Story
# 1         Lvl    AllPub       FR2       Gtl      Feedr       Norm     1Story
# 2         Lvl    AllPub    Inside       Gtl       Norm       Norm     2Story
# 3         Lvl    AllPub    Corner       Gtl       Norm       Norm     2Story
# 4         Lvl    AllPub       FR2       Gtl       Norm       Norm     2Story
#
#    OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle RoofMatl  \
# ...

# %%
combined['Garagetype']=-1

# %%
combined.GarageType.unique()
# Out:
# array(['Attchd', 'Detchd', 'BuiltIn', 'CarPort', nan, 'Basment', '2Types'], dtype=object)

# %%
combined.groupby('GarageType').count()
# Out:
#               Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# GarageType
# 2Types        23          23        23           23       23      23      2
# Attchd      1723        1723      1721         1723     1723    1723     33
# Basment       36          36        36           36       36      36      1
# BuiltIn      186         186       186          186      186     186      2
# CarPort       15          15        15           15       15      15      0
# Detchd       779         779       777          779      779     779    139
#
#             LotShape  LandContour  Utilities  LotConfig  LandSlope  \
# GarageType
# 2Types            23           23         23         23         23
# Attchd          1723         1723       1722       1723       1723
# Basment           36           36         36         36         36
# BuiltIn          186          186        186        186        186
# CarPort           15           15         15         15         15
# ...

# %%
combined['GarageType']=combined.GarageType.fillna('Attchd')

# %%
combined['Garagetype'][combined['GarageType'] == 'Attchd'] = 1
combined['Garagetype'][combined['GarageType'] == 'Detchd'] = 2
combined['Garagetype'][combined['GarageType'] == 'BuiltIn'] = 3
combined['Garagetype'][combined['GarageType'] == 'CarPort'] = 4 
combined['Garagetype'][combined['GarageType'] == 'Basment'] = 5
combined['Garagetype'][combined['GarageType'] == '2Types'] = 6

# %%
combined.drop('GarageType',1,inplace=True)

# %%
combined.KitchenQual.unique()
# Out:
# array(['Gd', 'TA', 'Ex', 'Fa', nan], dtype=object)

# %%
combined.groupby('KitchenQual').count()
# Out:
#                Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# KitchenQual
# Ex            205         205       205          205      205     205      6
# Fa             70          70        69           70       70      70      8
# Gd           1151        1151      1151         1151     1151    1151     80
# TA           1492        1492      1489         1492     1492    1492    104
#
#              LotShape  LandContour  Utilities  LotConfig  LandSlope  \
# KitchenQual
# Ex                205          205        205        205        205
# Fa                 70           70         70         70         70
# Gd               1151         1151       1151       1151       1151
# TA               1492         1492       1490       1492       1492
#
#              Condition1  Condition2  HouseStyle  OverallQual  OverallCond  \
# KitchenQual
# Ex                  205         205         205          205          205
# ...

# %%
combined['KitchenQual']=combined.KitchenQual.fillna('TA')

# %%
combined.KitchenQual =combined.KitchenQual.map({'Ex':1, 'Fa':2, 'Gd':3, 'TA':4}).astype(int)

# %%
combined['Saletype']=-1

# %%
combined['Salecondition']=-1

# %%
combined.groupby('SaleType').count()
# Out:
#             Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# SaleType
# COD         87          87        87           87       87      87     12
# CWD         12          12        12           12       12      12      1
# Con          5           5         5            5        5       5      1
# ConLD       26          26        25           26       26      26      3
# ConLI        9           9         9            9        9       9      1
# ConLw        8           8         8            8        8       8      0
# New        239         239       239          239      239     239     14
# Oth          7           7         7            7        7       7      0
# WD        2526        2526      2523         2526     2526    2526    166
#
#           LotShape  LandContour  Utilities  LotConfig  LandSlope  Condition1  \
# SaleType
# COD             87           87         87         87         87          87
# ...

# %%
combined.SaleType.unique()
# Out:
# array(['WD', 'New', 'COD', 'ConLD', 'ConLI', 'CWD', 'ConLw', 'Con', 'Oth'], dtype=object)

# %%
combined['Saletype'][combined['SaleType'] == 'COD'] = 1
combined['Saletype'][combined['SaleType'] == 'CWD'] = 2
combined['Saletype'][combined['SaleType'] == 'Con'] = 3
combined['Saletype'][combined['SaleType'] == 'ConLD'] = 4 
combined['Saletype'][combined['SaleType'] == 'ConLI'] = 5
combined['Saletype'][combined['SaleType'] == 'ConLw'] = 6
combined['Saletype'][combined['SaleType'] == 'New'] = 7
combined['Saletype'][combined['SaleType'] == 'Oth'] = 8
combined['Saletype'][combined['SaleType'] == 'WD'] = 9

# %%
combined.drop('SaleType',1,inplace=True)

# %%
combined.SaleCondition.unique()
# Out:
# array(['Normal', 'Abnorml', 'Partial', 'AdjLand', 'Alloca', 'Family'], dtype=object)

# %%
combined['Salecondition'][combined['SaleCondition'] == 'Normal'] = 1
combined['Salecondition'][combined['SaleCondition'] == 'Abnorml'] = 2
combined['Salecondition'][combined['SaleCondition'] == 'Partial'] = 3
combined['Salecondition'][combined['SaleCondition'] == 'AdjLand'] = 4 
combined['Salecondition'][combined['SaleCondition'] == 'Alloca'] = 5
combined['Salecondition'][combined['SaleCondition'] == 'Family'] = 6

# %%
combined.drop('SaleCondition',1,inplace=True)

# %%
combined.Heating.unique()
# Out:
# array(['GasA', 'GasW', 'Grav', 'Wall', 'OthW', 'Floor'], dtype=object)

# %%
combined['HeatingType']=-1

# %%
combined['HeatingType'][combined['Heating'] == 'GasA'] = 1
combined['HeatingType'][combined['Heating'] == 'GasW'] = 2
combined['HeatingType'][combined['Heating'] == 'Grav'] = 3
combined['HeatingType'][combined['Heating'] == 'Wall'] = 4 
combined['HeatingType'][combined['Heating'] == 'OthW'] = 5
combined['HeatingType'][combined['Heating'] == 'Floor'] = 6

# %%
combined.drop('Heating',1,inplace=True)

# %%
combined.CentralAir.unique()
# Out:
# array(['Y', 'N'], dtype=object)

# %%
combined.CentralAir =combined.CentralAir.map({'Y':1, 'N':0}).astype(int)

# %%
combined.head(5)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Condition1 Condition2 HouseStyle  \
# 0         Lvl    AllPub    Inside       Gtl       Norm       Norm     2Story
# 1         Lvl    AllPub       FR2       Gtl      Feedr       Norm     1Story
# 2         Lvl    AllPub    Inside       Gtl       Norm       Norm     2Story
# 3         Lvl    AllPub    Corner       Gtl       Norm       Norm     2Story
# 4         Lvl    AllPub       FR2       Gtl       Norm       Norm     2Story
#
#    OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle RoofMatl  \
# ...

# %%
combined.OverallQual.unique()
# Out:
# array([ 7,  6,  8,  5,  9,  4, 10,  3,  1,  2])

# %%
combined.OverallCond.unique()
# Out:
# array([5, 8, 6, 7, 4, 2, 3, 9, 1])

# %%
combined[combined.YearRemodAdd.isnull()]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Condition1, Condition2, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, BldgTypeCategory, NeighbourCity, Garagetype, Saletype, Salecondition, HeatingType]
# Index: []

# %%
combined.YearBuilt.unique()
# Out:
# array([2003, 1976, 2001, 1915, 2000, 1993, 2004, 1973, 1931, 1939, 1965,
#        2005, 1962, 2006, 1960, 1929, 1970, 1967, 1958, 1930, 2002, 1968,
#        2007, 1951, 1957, 1927, 1920, 1966, 1959, 1994, 1954, 1953, 1955,
#        1983, 1975, 1997, 1934, 1963, 1981, 1964, 1999, 1972, 1921, 1945,
#        1982, 1998, 1956, 1948, 1910, 1995, 1991, 2009, 1950, 1961, 1977,
#        1985, 1979, 1885, 1919, 1990, 1969, 1935, 1988, 1971, 1952, 1936,
#        1923, 1924, 1984, 1926, 1940, 1941, 1987, 1986, 2008, 1908, 1892,
#        1916, 1932, 1918, 1912, 1947, 1925, 1900, 1980, 1989, 1992, 1949,
#        1880, 1928, 1978, 1922, 1996, 2010, 1946, 1913, 1937, 1942, 1938,
#        1974, 1893, 1914, 1906, 1890, 1898, 1904, 1882, 1875, 1911, 1917,
#        1872, 1905, 1907, 1896, 1902, 1895, 1879, 1901])

# %%
combined.MasVnrArea.unique()
# Out:
# array([  1.96000000e+02,   0.00000000e+00,   1.62000000e+02,
#          3.50000000e+02,   1.86000000e+02,   2.40000000e+02,
#          2.86000000e+02,   3.06000000e+02,   2.12000000e+02,
#          1.80000000e+02,   3.80000000e+02,   2.81000000e+02,
#          6.40000000e+02,   2.00000000e+02,   2.46000000e+02,
#          1.32000000e+02,   6.50000000e+02,   1.01000000e+02,
#          4.12000000e+02,   2.72000000e+02,   4.56000000e+02,
#          1.03100000e+03,   1.78000000e+02,   5.73000000e+02,
#          3.44000000e+02,   2.87000000e+02,   1.67000000e+02,
#          1.11500000e+03,   4.00000000e+01,   1.04000000e+02,
#          5.76000000e+02,   4.43000000e+02,   4.68000000e+02,
#          6.60000000e+01,   2.20000000e+01,   2.84000000e+02,
#          7.60000000e+01,   2.03000000e+02,   6.80000000e+01,
#          1.83000000e+02,   4.80000000e+01,   2.80000000e+01,
#          3.36000000e+02,   6.00000000e+02,   7.68000000e+02,
# ...

# %%
combined['MasVnrArea']=combined.MasVnrArea.fillna(combined.MasVnrArea.mean())

# %%
combined[combined.TotalBsmtSF.isnull()]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 2120  2121          20       RM         99.0     5940   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig LandSlope Condition1 Condition2  \
# 2120         Lvl    AllPub       FR3       Gtl      Feedr       Norm
#
#      HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle  \
# 2120     1Story            4            7       1946          1950     Gable
#
#      RoofMatl Exterior1st Exterior2nd MasVnrType  MasVnrArea ExterQual  \
# 2120  CompShg     MetalSd      CBlock       None         0.0        TA
#
#      ExterCond Foundation BsmtQual BsmtCond BsmtExposure BsmtFinType1  \
# 2120        TA      PConc      NaN      NaN          NaN          NaN
#
#       BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF HeatingQC  \
# 2120         NaN          NaN         NaN        NaN          NaN        TA
#
# ...

# %%
combined['TotalBsmtSF']=combined.TotalBsmtSF.fillna(combined.TotalBsmtSF.median())

# %%
combined[combined.TotalBsmtSF.isnull()]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Condition1, Condition2, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, BldgTypeCategory, NeighbourCity, Garagetype, Saletype, Salecondition, HeatingType]
# Index: []

# %%
combined[combined['1stFlrSF'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Condition1, Condition2, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, BldgTypeCategory, NeighbourCity, Garagetype, Saletype, Salecondition, HeatingType]
# Index: []

# %%
combined['1stFlrSF'].unique()
# Out:
# array([ 856, 1262,  920, ..., 1778, 1650, 1960])

# %%
combined[combined['2ndFlrSF'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Condition1, Condition2, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, BldgTypeCategory, NeighbourCity, Garagetype, Saletype, Salecondition, HeatingType]
# Index: []

# %%
combined[combined.GrLivArea.isnull()]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Condition1, Condition2, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, BldgTypeCategory, NeighbourCity, Garagetype, Saletype, Salecondition, HeatingType]
# Index: []

# %%
combined[combined.FullBath.isnull()]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Condition1, Condition2, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, BldgTypeCategory, NeighbourCity, Garagetype, Saletype, Salecondition, HeatingType]
# Index: []

# %%
combined[combined.HalfBath.isnull()]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Condition1, Condition2, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, BldgTypeCategory, NeighbourCity, Garagetype, Saletype, Salecondition, HeatingType]
# Index: []

# %%
combined.BedroomAbvGr.unique()
# Out:
# array([3, 4, 1, 2, 0, 5, 6, 8])

# %%
combined.KitchenAbvGr.unique()
# Out:
# array([1, 2, 3, 0])

# %%
combined.TotRmsAbvGrd.unique()
# Out:
# array([ 8,  6,  7,  9,  5, 11,  4, 10, 12,  3,  2, 14, 13, 15])

# %%
combined[combined.GarageArea.isnull()]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 2576  2577          70       RM         50.0     9060   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Condition1 Condition2  \
# 2576         Lvl    AllPub    Inside       Gtl       Norm       Norm
#
#      HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle  \
# 2576     2Story            5            6       1923          1999     Gable
#
#      RoofMatl Exterior1st Exterior2nd MasVnrType  MasVnrArea ExterQual  \
# 2576  CompShg     Wd Sdng     Plywood       None         0.0        TA
#
#      ExterCond Foundation BsmtQual BsmtCond BsmtExposure BsmtFinType1  \
# 2576        TA     BrkTil       Gd       TA           No          ALQ
#
#       BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF HeatingQC  \
# 2576       548.0          Unf         0.0      311.0        859.0        Ex
#
# ...

# %%
combined['GarageArea']=combined.GarageArea.fillna(combined.GarageArea.median())

# %%
combined[combined.GarageArea.isnull()]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Condition1, Condition2, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, BldgTypeCategory, NeighbourCity, Garagetype, Saletype, Salecondition, HeatingType]
# Index: []

# %%
combined.PoolArea.unique()
# Out:
# array([  0, 512, 648, 576, 555, 480, 519, 738, 144, 368, 444, 228, 561, 800])

# %%
combined.YrSold.unique()
# Out:
# array([2008, 2007, 2006, 2009, 2010])

# %%
train = combined.ix[0:1459]
test= combined.ix[1460:]
target_value=  pd.read_csv('./train.csv').SalePrice
pids = pd.read_csv('./test.csv').Id
passId = pids.values

# %%
My_features= train[['MSSubClass','LotFrontage','LotArea','OverallQual','OverallCond','YearBuilt','YearRemodAdd','MasVnrArea','TotalBsmtSF','CentralAir','1stFlrSF', '2ndFlrSF', 'GrLivArea', 'FullBath', 'HalfBath', 'BedroomAbvGr','KitchenAbvGr', 'KitchenQual','TotRmsAbvGrd','GarageArea', 'PoolArea','YrSold','BldgTypeCategory','NeighbourCity','Garagetype','Saletype','Salecondition','HeatingType']]
#

# %%
features=My_features.values

# %%
df_out = target_value

# %%
df_out.shape
# Out:
# (1460,)

# %%
My_features.shape
# Out:
# (1460, 28)

# %%
clf = RandomForestClassifier()

# %%
clf=clf.fit(features, df_out)

# %%
for header, value in zip(My_features.columns,clf.feature_importances_):
    print (header," : ", value)
# Out:
# MSSubClass  :  0.0242453664344
# LotFrontage  :  0.0665647124622
# LotArea  :  0.0784978972905
# OverallQual  :  0.0370611062394
# OverallCond  :  0.0336729137656
# YearBuilt  :  0.0678858553014
# YearRemodAdd  :  0.055279046163
# MasVnrArea  :  0.0436452333548
# TotalBsmtSF  :  0.0740732115901
# CentralAir  :  0.00561608813835
# 1stFlrSF  :  0.0734252579504
# 2ndFlrSF  :  0.0333560658224
# GrLivArea  :  0.0729060648662
# FullBath  :  0.008848278169
# HalfBath  :  0.0137156672221
# BedroomAbvGr  :  0.0236039503274
# KitchenAbvGr  :  0.00382547766644
# KitchenQual  :  0.0194995669803
# TotRmsAbvGrd  :  0.0417663480763
# GarageArea  :  0.0738367775822
# PoolArea  :  0.00146424284171
# YrSold  :  0.0430255838996
# BldgTypeCategory  :  0.00756776189686
# NeighbourCity  :  0.0442064803163
# Garagetype  :  0.018709414074
# Saletype  :  0.0122375433136
# Salecondition  :  0.0171515595086
# HeatingType  :  0.00431252874682

# %%
test_features=test[['MSSubClass','LotFrontage','LotArea','OverallQual','OverallCond','YearBuilt','YearRemodAdd','MasVnrArea','TotalBsmtSF','CentralAir','1stFlrSF', '2ndFlrSF', 'GrLivArea', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr','KitchenQual','TotRmsAbvGrd','GarageArea','PoolArea', 'YrSold','BldgTypeCategory','NeighbourCity','Garagetype','Saletype','Salecondition','HeatingType']]

# %%
Output = clf.predict(test_features)

# %%
Output.shape
# Out:
# (1459,)

# %%
passId.shape
# Out:
# (1459,)

# %%
result = pd.DataFrame(columns=['Id', 'SalePrice'])
result['Id'] = passId
result['SalePrice'] = Output.astype(int)
result.to_csv('HousePrice.csv', index=False)
# print(result) 
# test['SalePrice']=result['SalePrice']

# %%
# test.head(5)

# %%
print(result)
# Out:
#         Id  SalePrice
# 0     1461      84000
# 1     1462     150000
# 2     1463     181000
# 3     1464     181000
# 4     1465     180000
# 5     1466     185000
# 6     1467     173000
# 7     1468     174000
# 8     1469     180000
# 9     1470      97000
# 10    1471     180000
# 11    1472      85400
# 12    1473      88000
# 13    1474     146000
# 14    1475      91000
# 15    1476     412500
# 16    1477     287090
# 17    1478     107000
# 18    1479     216837
# 19    1480     386250
# 20    1481     306000
# 21    1482     202500
# 22    1483     169990
# 23    1484     160200
# 24    1485     180000
# 25    1486     183500
# 26    1487     340000
# 27    1488     230000
# 28    1489     157000
# 29    1490     196000
# 30    1491     180000
# 31    1492     115000
# 32    1493     110000
# 33    1494     290000
# 34    1495     179900
# 35    1496     196000
# 36    1497     151000
# 37    1498     151000
# 38    1499     147400
# 39    1500     147400
# ...
